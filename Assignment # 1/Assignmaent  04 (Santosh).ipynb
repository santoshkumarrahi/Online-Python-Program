# %%
#Question No:- 01 
Outer_dictionary = {
    101: {"name": "Laptop", "category": "Electronics", "price": 1200, "stock": 50},
    102: {"name": "Shirt", "category": "Apparel", "price": 25, "stock": 200},
    103: {"name": "Coffee Maker", "category": "Home Appliances", "price": 80, "stock": 30},
}
Outer_dictionary[102]["stock"] = 250
inner_Dictonay = {
    104: {'name': 'Smartphone', 'category': 'Electronics', 'price': 800, 'stock': 100},
}
Outer_dictionary.update(inner_Dictonay)
print("",Outer_dictionary)
# Out:
# {101: {'name': 'Laptop', 'category': 'Electronics', 'price': 1200, 'stock': 50}, 102: {'name': 'Shirt', 'category': 'Apparel', 'price': 25, 'stock': 250}, 103: {'name': 'Coffee Maker', 'category': 'Home Appliances', 'price': 80, 'stock': 30}, 104: {'name': 'Smartphone', 'category': 'Electronics', 'price': 800, 'stock': 100}}

# %%
#Question No:- 02
employee = ("Ali", 25, "Data Analyst", 75000)
name,age,job,salary = employee
increase = salary * 0.10
update_salary = salary + increase
print(update_salary)
# Out:
# 82500.0

# %%
#Question No:- 03
shop_list = ["apple", "banana", "apple", "orange", "banana", "grape"]
set(shop_list)
# Out:
# {'apple', 'banana', 'grape', 'orange'}

# %%
#Question No:- 04
course_a = {"John", "Alice", "Bob", "David"}
course_b = {"Alice", "Eve", "Charlie", "David"}
print(course_a.difference(course_b))
print(course_a.symmetric_difference(course_b))
# Out:
# {'Bob', 'John'}
# {'John', 'Bob', 'Eve', 'Charlie'}

# %%
#Question No:- 05
numbers = (10, 20, 30, 40, 50, 60, 70)
print("Display the first 3 elements : ",numbers[:3])
print("Display the last 3 elements : ",numbers[-3:])
print("Display alternate elements : ",numbers[::2])
# Out:
# Display the first 3 elements :  (10, 20, 30)
# Display the last 3 elements :  (50, 60, 70)
# Display alternate elements :  (10, 30, 50, 70)

# %%
#Question No:- 06
student_details = {
    "Ali": {"age": 20, "grade": "A", "city": "Karachi"},
    "Sara": {"age": 21, "grade": "B", "city": "Lahore"},
    "Omar": {"age": 19, "grade": "A", "city": "Islamabad"},
    "Hina": {"age": 22, "grade": "C", "city": "Faisalabad"},
}
print(student_details)
# Out:
# {'Ali': {'age': 20, 'grade': 'A', 'city': 'Karachi'}, 'Sara': {'age': 21, 'grade': 'B', 'city': 'Lahore'}, 'Omar': {'age': 19, 'grade': 'A', 'city': 'Islamabad'}, 'Hina': {'age': 22, 'grade': 'C', 'city': 'Faisalabad'}}

# %%
new_student = {
   "Zara": {"age": 20, "grade": "B", "city": "Multan"},
    
}
print(new_student)
# Out:
# {'Zara': {'age': 20, 'grade': 'B', 'city': 'Multan'}}

# %%
print(student_details)
# Out:
# {'Ali': {'age': 20, 'grade': 'A', 'city': 'Karachi'}, 'Sara': {'age': 21, 'grade': 'B', 'city': 'Lahore'}, 'Omar': {'age': 19, 'grade': 'A', 'city': 'Islamabad'}, 'Hina': {'age': 22, 'grade': 'C', 'city': 'Faisalabad'}}

# %%
del student_details["Omar"]

# %%
print(student_details)
# Out:
# {'Ali': {'age': 20, 'grade': 'A', 'city': 'Karachi'}, 'Sara': {'age': 21, 'grade': 'B', 'city': 'Lahore'}, 'Hina': {'age': 22, 'grade': 'C', 'city': 'Faisalabad'}, 'Zara': {'age': 20, 'grade': 'B', 'city': 'Multan'}}

# %%
student_details.update(new_student)
print(student_students)
# Out:
# None

# %%
#Question No:- 07
# Inventory dictionary
inventory = {
            "The Great Gatsby":{"price":10.99,"quantity":5.5},
             "Rich dad poor dad":{"price":8.99,"quantity":8},
             "Harrypotter":{"price":12.50,"quantity":2},

}
inventory
# Out:
# {'The Great Gatsby': {'price': 10.99, 'quantity': 5.5},
#  'Rich dad poor dad': {'price': 8.99, 'quantity': 8},
#  'Harrypotter': {'price': 12.5, 'quantity': 2}}

# %%
new_book = {
    "Data Analytics Batch":{"price":7999,"quantity":26}
}
print(new_book)
# Out:
# {'Data Analytics Batch': {'price': 7999, 'quantity': 26}}

# %%
inventory.update(new_book)
print(inventory)
# Out:
# {'The Great Gatsby': {'price': 10.99, 'quantity': 5.5}, 'Rich dad poor dad': {'price': 8.99, 'quantity': 8}, 'Harrypotter': {'price': 12.5, 'quantity': 2}, 'Data Analytics Batch': {'price': 7999, 'quantity': 26}}

# %%
titles = inventory.keys()
print(titles)
# Out:
# dict_keys(['The Great Gatsby', 'Rich dad poor dad', 'Harrypotter'])

# %%
#Question No:- 08
d = {"x": 1, "y": 2}
items = d.items()
print(items)
# Out:
# dict_items([('x', 1), ('y', 2)])

# %%
#Question No:- 09
A = {"Ali", "Sara"} 
B = {"Ahmed", "Zara"}
A.union(B)
# Out:
# {'Ahmed', 'Ali', 'Sara', 'Zara'}

# %%
#Question No:- 10
A = {1, 2, 3, 4, 5}
B = {4, 5, 6, 7}
print("Find the Common Elements : ",A.intersection(B))
print("Find the Elements only in Set A : ",A.difference(B))
print("Find the Elements only in Set A : ",B.difference(A))
# Out:
# Find the Common Elements :  {4, 5}
# Find the Elements only in Set A :  {1, 2, 3}
# Find the Elements only in Set A :  {6, 7}
