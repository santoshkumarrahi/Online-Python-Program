# %%
#Question 1
#Calculate and write the output of the following expression:
#0 + 4 × 3 − 6
result_1 =  0 + 4 * 3 - 6
print("Expression : ",result_1)
# Out:
# Expression :  6

# %%
#Question 2 
#Calculate and write the output of the following expression:
#100 ÷ 4 + 7 − 5
result_2 = 100 / 4 + 7 - 5
print("Expression : ",result_2 )
# Out:
# Expression :  27.0

# %%
#Question 3
#Create a variable containing the string value "100". Convert it into an integer and display its data type before and after conversion.
value = "100"
print("Befor Conversion : ",type(value),value)
value =int(value)
print("After Conversion : ",type(value),value)
# Out:
# Befor Conversion :  <class 'str'> 100
# After Conversion :  <class 'int'> 100

# %%
#Question 4
#Create the following list and display:
#cities = ["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]
#Second city
#Fourth city
cities = ["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]
print("The Second City Name is : ",cities[1])
print("The Fourth City Name is : ",cities[4])
# Out:
# The Second City Name is :  Lahore
# The Fourth City Name is :  Quetta

# %%
#Question 5
#Create the following nested list and display:
#students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
#Ali
#Ayesha
students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
print("Print the Name is : ",students[0][0])
print("Print the Name is : ",students[1][0])
# Out:
# Print the Name is :  Ali
# Print the Name is :  Ayesha

# %%
# Question 6
#Given list:
#numbers = [10, 20, 30, 40, 50, 60, 70]
#Display:
#First 3 elements
#Last 3 elements
numbers = [10, 20, 30, 40, 50, 60, 70]
print("Print First Three Elements : ",numbers[:3])
print("Print Last Three Elements : ",numbers[-3:])
# Out:
# Print First Three Elements :  [10, 20, 30]
# Print First Three Elements :  [50, 60, 70]

# %%
#Question 7
#Given nested list::
#students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
#Display:
#Name of first student
#Age of second student
students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
print("Display : ",students)
print("First Student Name is : ",students[0][0])
print("Second Student Age is : ",students[1][1])
# Out:
# Display :  [['Ali', 20], ['Ayesha', 22], ['Ahmed', 21]]
# First Student Name is :  Ali
# Second Student Age is :  22
