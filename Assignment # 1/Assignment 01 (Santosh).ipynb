# %%
#Question No: 01
#sum
num1 = int(input("Enter your First Number : "))
num2 = int(input("Enter your Second Number : "))
sum  = num1 + num2
print("Sum is : ",sum)
# Out:
# Enter your First Number :  25
# Enter your Second Number :  35
# Sum is :  60

# %%
#Difference
num1 = int(input("Enter your First Number : "))
num2 = int(input("Enter your Second Number : "))
diff  = num1 - num2
print("Minus is : ",diff)
# Out:
# Enter your First Number :  25
# Enter your Second Number :  13
# Minus is :  12

# %%
#Product
num1 = int(input("Enter your First Number : "))
num2 = int(input("Enter your Second Number : "))
pro  = num1 * num2
print("Product is : ",pro)
# Out:
# Enter your First Number :  2
# Enter your Second Number :  5
# Product is :  10

# %%
#Division
num1 = int(input("Enter your First Number : "))
num2 = int(input("Enter your Second Number : "))
div  = num1 / num2
print("Division is : ",div)
# Out:
# Enter your First Number :  25
# Enter your Second Number :  5
# Division is :  5.0

# %%
# floor Division
num1 = int(input("Enter your First Number : "))
num2 = int(input("Enter your Second Number : "))
flo_div  = num1 // num2
print("Division is : ",flo_div)
# Out:
# Enter your First Number :  15
# Enter your Second Number :  4
# Division is :  3

# %%
#Modulus
num1 = int(input("Enter your First Number : "))
num2 = int(input("Enter your Second Number : "))
modu  = num1 / num2
print("Division is : ",modu)
# Out:
# Enter your First Number :  10
# Enter your Second Number :  3
# Division is :  3.3333333333333335

# %%
#Question No: 02
fav_food = input("Enter your Favourite Food: ")
print("Your Favourite Food is : ", fav_food)
# Out:
# Enter your Favourite Food:  Rice
# Your Favourite Food is :  Rice

# %%
#Question No: 03
num1 = int(input("Enter you Have Mangoes: "))
num2 = int(input("Enter your Have Apples : "))
total  = num1 + num2
print("Total is : ",total)
# Out:
# Enter you Have Mangoes:  33
# Enter your Have Apples :  22
# Total is :  55

# %%
#Question 04
#check only type
num1 = 10
num2 = 5.2
num3 = 4.43
num4 = "123"
print(type(num1))
print(type(num2))
print(type(num3))
print(type(num4))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'str'>

# %%
#1 Integer to Float
num1_int = int(num1)
print(num1_int)
num1_int = float(num1_int)
print(type(num1_int),num1_int)
# Out:
# 10
# <class 'float'> 10.0

# %%
#2 Float to Integer 
num2_float = float(num2)
print(num2_float)
num2_float = int(num2_float)
print(type(num2_float),num2_float)
# Out:
# 5.2
# <class 'int'> 5

# %%
#3 Float to String
num3_str = str(num3)
print(num3_str)
num3_str = str(num3_str)
print(type(num3_str),num3_str)
# Out:
# 4.43
# <class 'str'> 4.43

# %%
#3 String to integer
num4_str = str(num4)
print(type(num4_str),num4_str)
num4_str = int(num4_str)
print(type(num4_str),num4_str)
# Out:
# <class 'str'> 123
# <class 'int'> 123

# %%
# Question No:- 05
name = input("Enter your Name : ")
age  = int(input("Enter your Final Age : "))
print("Your Name is : ",name)
print("Your Final Age is : ",age)
# Out:
# Enter your Name :  Santosh
# Enter your Final Age :  25
# Your Name is :  Santosh
# Your Final Age is :  25

# %%
# Question No:- 06
a = 2
b = 1
c = 6
d = 3
#Add a and b
print("Add : ",a + b)
print("Substract : ",a - c)
print("Multiply : ",d + b)
print("Divide : ",c / d)
print("Divide : ",c % d)
print("Square : ",c ** d)
# Out:
# Add :  3
# Substract :  -4
# Multiply :  4
# Divide :  2.0
# Divide :  0
# Square :  216

# %%
#Qustion No:- 07
your_age = int (input ("Enter Your Age is : "))
your_age = your_age + 5
print("Your Current Age is : ",your_age)
# Out:
# Enter Your Age is :  25
# Your Current Age is :  30

# %%
#Qustion No:- 08
#conversion
a = '12'
b = '11'
c = 6.3
# string to integer
a = int(a)
print(type(a),a)
# string to float
b = float(b)
print(type(b),b)
# float to integer
c = int(c)
print(type(c),c)
# Out:
# <class 'int'> 12
# <class 'float'> 11.0
# <class 'int'> 6

# %%
#addition
print("Add is : ",a + b)
print("Multiply is : ",b + c)
print("Add is : ",c + c)
# Out:
# Add is :  23.0
# Multiply is :  17.0
# Add is :  12

# %%
#Qustion No:- 09
books = int (input("How Many Have You Total Books : "))
books = books -4
print("You Have Books Now : ",books)
# Out:
# How Many Have You Total Books :  20
# You Have Books Now :  16

# %%
#Qustion No:- 09
cookies = int (input("How Many Have You Cookies : "))
cookies = cookies * 3
print("You Have Total Booked Cookies : ",cookies)
# Out:
# How Many Have You Cookies :  5
# You Have Total Booked Cookies :  15

# %%
#Question No:- 11
expression = 20 - 4 * (3 + 2) + 18 / 3
print(expression)
# Out:
# 6.0
