# %%
# Question Number : 01
age = int (input("Enter your age : "))
if age> 0 and age <= 12:
    print("Child")
elif age >= 13 and age <= 19:
    print("Teenager")
elif age > 20 and age <= 64:
    print("Adult")
elif age > 65:
    print("Senior")
else:
    print("Age is not Valid")
# Out:
# Enter your age :  45
# Adult

# %%
# Question Number : 02
num1 =int(input("Enter your 1st number : "))
num2 =int(input("Enter your 2nd number : "))
num3 =int(input("Enter your 3rd number : "))
if num1 >= num2 and num1 >=num3:
    print("Number (1) is greator : ",num1)
elif num2 >= num1 and num2 >= num3:
    print("Number (2) is greator : ",num2)
else:
    print("Number (3) is greator : ",num3)
if num1 == num2 == num3:
    print("All numbers are equal")
elif num1== num2 or num1 == num3 or num2== num3:
    print("Two numbers are equals")
else:
    print("All numbers are different")
# Out:
# Enter your 1st number :  25
# Enter your 2nd number :  25
# Enter your 3rd number :  14
# Number (1) is greator :  25
# Two numbers are equals

# %%
# Question Number : 03
my_tuple = (5,10,15,20,25)
your_tuple = int(input("Enter your number : "))
if your_tuple in my_tuple:
    print("Value Exist")
else:
    print("Value Does not Exist")
# Out:
# Enter your number :  35
# Value Does not Exist

# %%
# Question Number : 04
title = input("Enter your Title  your of Book : ")
author = input("Enter your Author your of Book : ")
price = int (input("Enter Price of your Book : "))
year = int (input("Enter Publication Year of your Book : "))
book = (title,author,price,year)
print("Tittles: ",book[0])
;print("Author: ",author[1])
print("Price $: ",book[2])
print("Year: ",book[3])
# Out:
# Enter your Title  your of Book :  Harry Potter
# Enter your Author your of Book :  Jk Rowlings
# Enter Price of your Book :  8000
# Enter Publication Year of your Book :  2000
# Tittles:  Harry Potter
# Author:  k
# Price $:  8000
# Year:  2000

# %%
# Question Number : 05
list_subject = ["English","Math","Urdu","Art","Sindhi"]
subject = input("Enter your subject : ")
if subject in list_subject:
    print(subject,"is Available")
else:
    print("not Valid",subject)
# Out:
# Enter your subject :  Art
# Art is Available

# %%
# Question Number : 06
number = int (input("Enter your number : "))
if number > 0:
    print("Positive")
elif number < 0:
    print("Negative")
elif number == 0 :
    print("Zero")
else:
    print("Invalid")
# Out:
# Enter your number :  0
# Zero

# %%
# Question Number : 07
username = input("Enter your user name : ")
password = input("Enter your password : ")
if username == "admin" and password == "admin@123":
    print("Login Sucessfull")
elif username != "admin" and password == "admin@a123":
    print("Invalid Username")
elif username == "admin" and password != "admin@a123":
    print("Invalid Password")
elif username != "admin" and password != "admin@a123":
    print("Invalid Username & Invalid Password")
else:
    print("inValid")
# Out:
# Enter your user name :  admin
# Enter your password :  admin@123
# Login Sucessfull

# %%
# Question Number : 08
age = int (input("Enter your age : "))
credit_score = int(input("Enter your Credit Score : "))
income = int(input("Enter your Income : "))
if age >= 18 and credit_score >=650 and income>=30000:
    print("Your are eligible for loan")
elif age >= 18 and credit_score >=700 and income>=250000:
    print("Your are eligible for loan")
else:
    print("not eligible for loan")
# Out:
# Enter your age :  18
# Enter your Credit Score :  800
# Enter your Income :  320000
# Your are eligible for loan

# %%
letter = input("Enter your single letter : ")
if (
    letter.upper() == "A" or letter.lower() == "a" or
    letter.upper() == "E" or letter.lower() == "e" or
    letter.upper() == "I" or letter.lower() == "i" or
    letter.upper() == "O" or letter.lower() == "o" or
    letter.upper() == "U" or letter.lower() == "u"
):
    print("vowel")
elif letter.isalpha():
    print("Consonent")
else:
    print("Valid Alphabet")
# Out:
# Enter your single letter :  y
# Consonent
